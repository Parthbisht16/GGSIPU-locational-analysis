# %% [markdown]
# <a href="https://colab.research.google.com/github/Parthbisht16/GGSIPU-locational-analysis/blob/main/GGSIPU_locational_analysis_FINAL_Copy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/GGSIPU_locational_analysis_FINAL.ipynb)

# %% [markdown]
# ## Exploratory Analysis of Geolocational Data

# %% [markdown]
# ## Introduction :
#
# This project involves the use of K-Means Clustering to find the best accommodation for
# students in Delhi (or any other city of your choice) by classifying accommodation for
# incoming students on the basis of their preferences on amenities, budget and proximity to
# the location.

# %% [markdown]
# Let us first import all the packages we need for analysis.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
import geopandas as gpd
import matplotlib.cm as cm
import folium
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image 
from IPython.core.display import HTML 
# tranforming json file into a pandas dataframe library
from pandas import json_normalize
from sklearn.metrics import confusion_matrix,classification_report
print("All packages imported!")
# Out:
# All packages imported!

# %% [markdown]
# Alright, now let us import the raw dataset for student preferences...

# %%
dfstudents=pd.read_csv('food_coded.csv')

# %% [markdown]
# We shall only take the columns useful to us:

# %%
dfclean=dfstudents[['cook','eating_out','employment','ethnic_food','exercise','fruit_day','income','on_off_campus','pay_meal_out','sports','veggies_day']]
dfclean.dropna(axis=0,inplace=True)
dfclean.head()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\3365265966.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfclean.dropna(axis=0,inplace=True)
#    cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 0   2.0           3         3.0            1       1.0          5     5.0
# 1   3.0           2         2.0            4       1.0          4     4.0
# 2   1.0           2         3.0            5       2.0          5     6.0
# 3   2.0           2         3.0            5       3.0          4     6.0
# 4   1.0           2         2.0            4       1.0          4     6.0
#
#    on_off_campus  pay_meal_out  sports  veggies_day
# 0            1.0             2     1.0            5
# 1            1.0             4     1.0            4
# 2            2.0             3     2.0            5
# 3            1.0             2     2.0            3
# 4            1.0             4     1.0            4

# %% [markdown]
# ## Identifying the different kinds of students

# %% [markdown]
# Let us visualise the distrubtion of data with a boxplot:

# %%
plt.figure(figsize=(20, 10))
#plt.xticks(rotation='vertical')
sns.boxplot

ax = sns.boxplot(data = dfclean)
ax.tick_params(labelsize=20)
plt.xticks(rotation=45, ha='right')

plt.show()

# %%
# set number of clusters
kclusters = 3

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(dfclean)
dfclean['Cluster']=kmeans.labels_
# Out:
# C:\Users\Acer\anaconda3\envs\myenv\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\1730389316.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfclean['Cluster']=kmeans.labels_

# %%
fig, axes = plt.subplots(1,kclusters, figsize=(20, 10), sharey=True)
axes[0].set_ylabel('Coded Values', fontsize=25)

for k in range(kclusters):
     plt.sca(axes[k])
     plt.xticks(rotation=45,ha='right')
     sns.boxplot(data = dfclean[dfclean['Cluster'] == k].drop('Cluster',1), ax=axes[k])
        
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\4201883230.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   sns.boxplot(data = dfclean[dfclean['Cluster'] == k].drop('Cluster',1), ax=axes[k])
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\4201883230.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   sns.boxplot(data = dfclean[dfclean['Cluster'] == k].drop('Cluster',1), ax=axes[k])
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\4201883230.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   sns.boxplot(data = dfclean[dfclean['Cluster'] == k].drop('Cluster',1), ax=axes[k])

# %% [markdown]
# **Possible insights:**
#
# Kmeans:
# 2 clusters: No clear demarcation is seen; we can't discriminate on 2 categories alone.
#
# 3 clusters: Now we see three clear groups: One high income group which insists on eating healthy, the other is more relaxed in diet.
#
# The low income group has its own profile, as discussed in insights.
#
# For higher numbers of clusters, it becomes difficult to draw any concrete conclusions.
#
#
#
# High income students in general are:
#
# 1.>Much more likely to stay on campus.
#
# 2.>Less likely to cook.
#
# 3.>Eat out more often.
#
# In addition, a subset of higher income students:
# 1.>Eat out less often.
#
# 2.>Have a healthier, more varied diet in general. (Eat ethnic food, fruits, vegetables etc.)
#
# Lower income students are more likely to:
#
# 1.>Eat more vegetables
#
# 2.>Eat more fruits.
#
# 3.>More likely to cook, so more likely to stay off campus.
#
# 4.>Obviously, pay less for meals out.

# %% [markdown]
# Essentially, we need to think about accomodation for 2 types of students, low income and high income(varied diet).
#
# The high income(fixed diet) students will ideally stay on campus, so they don't have to be taken into account.

# %% [markdown]
# # Finding the students a apartment

# %% [markdown]
# My analysis will be on the city I currently reside in, i.e Delhi, India!
#
# Specifically, I will begin by looking at the housing areas around GGSIPU.
#
# We begin by defining the parameters of our foursquare seach query:

# %%
search_query = 'Apartment' #Search for residential locations
radius = 20000 #Set the radius to 20 kilometres due to traffic constraints
latitude=28.594899#GGSIPU location
longitude=77.021327

# %% [markdown]
# Now to define our foursquare credentials:

# %%
CLIENT_ID='YVXU3P2WSRWZAFQPVSSO3HHUVWZ5TIMEW1NNKENYURXHMMKD'
CLIENT_SECRET='Q3ABL5LX1B2AXBEOTM3AIL3NM2DYAJ2JEYJNFMPHYWZJRXHR'
VERSION = '20180604'
LIMIT = 200

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

# %%
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']
n = 200
# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head(n = n)
# Out:
#                           id  \
# 0   4edb45ac0aaf49e02aa30cc3
# 1   5184977d498ec7f6416fdcba
# 2   4efe8845b6346feaeba89dc0
# 3   4efe88f3775bec6b42df0632
# 4   5187df94498e3dfc9e0f525a
# 5   516a4e8ee4b01de80d736d8e
# 6   578ee93c498e2a11e7647c58
# 7   5fcbc2c14a774867c404be66
# 8   4ffb9c40e4b02d09f9b5ff9e
# 9   5736bade498e8349f57ac805
# 10  4c4ac136712ac9289c08e96b
# 11  5117d231e4b05b41f518d44a
# 12  59733a8ceacf453223eced6f
# 13  5524d6d1498e63d1181af446
# 14  5c43189dbed483002cbccbe6
# 15  4d73a5a85838a093a9a91bdb
# 16  518f6480498e01b5206fb6dc
# 17  52072b3211d27144358667a1
# 18  4e2c294045dd3272c819f73d
# 19  4f76cc8ae4b07024f9ebc63c
# 20  52b9e116498e97c256cfe787
# 21  4f3522f5e4b0cbcdf07934ca
# 22  5038dd2be4b03267a8a2c78e
# 23  4deae91d88774880e32a49a0
# 24  4f3523f8e4b0ba1c47e23658
# 25  504320efe4b043734b779629
# 26  51694ebce4b0c884cc777a0f
# 27  50004cbfe4b086e5a770dfe0
# 28  50f2c04de4b0d3754e3b94b0
# 29  5220e0df11d2303d8d1bc3cf
# 30  55fa984c498e3cf080b0c6e6
# 31  5659a3f6498e4fd2385189ef
# 32  4df77345d22df20cc2d76c35
# 33  4be070414c55b651536feab7
# 34  5058947ae4b0b2cff7f523e0
# 35  4f849baee5e8be643de1b858
# 36  4df8131d18385456c7f3d470
# 37  536d260f11d2642ca67193e9
# 38  4d3b32fc687ca35dc88891c4
# 39  5b82b4f71fa76300395ac927
# 40  4decf457fa76cc1b8b236e80
# 41  4e1b687218a8ce9e3860a54d
# 42  4e59fbf818a8c204751381dc
# 43  4e61fc66d22d509a396a222c
# 44  4df4607688772e1f81574569
# 45  518a94a1498e5063a8a381f7
# 46  4df6314ca809141629ab4dd2
# 47  4e1cf2bac65b6cd0da96baa8
# 48  52bfdb2e498e3dae8e50b3c6
# 49  4f43e6a8e4b011b008069090
#
#                                                  name  \
# 0                                  Ispatika Apartment
# 1                            Shivam,Apartment, Sec 12
# 2   National Apartment Sector 3, Near sec3/13 traf...
# 3                  national apartment sector 3 dwarka
# 4                              The Stoners apartment.
# 5                           gokul apartment sector 11
# 6                               South Delhi Apartment
# 7               Oyo 37722 Silver Oak Luxury Apartment
# 8                  skylark apartment dwarka sector 06
# 9                                Sukh Sagar Apartment
# 10                                 Airlines Apartment
# 11                           New Millenium Apartments
# 12                         Ramakrishan Cghs Apartment
# 13                     St. Columba's School Apartment
# 14                                Kautilya Apartments
# 15                                Highland Apartments
# 16                                  Sunder Apartments
# 17                              Prem Milan Apartments
# 18                              Gold Croft Apartments
# 19          Admiral apartment, emeryville, california
# 20                                Radisson Apartments
# 21        Air India Apartments,Sector 3,Plot 9,Dwarka
# 22                             Silver Arch Apartments
# 23                             Dakshinayan Apartments
# 24        Air India Apartments,Sector 3,Plot 9,Dwarka
# 25                                 Sunrise Apartments
# 26              National Apartments, Sector 3, Dwarka
# 27              himachali apartments, dwarka sector-3
# 28                               Air India Apartments
# 29                                Sun View Apartments
# 30                              Akshardham Apartments
# 31                                     DPS Apartments
# 32                                    Rama Apartments
# 33                             Apartment 52 New Delhi
# 34                                     PNB Apartments
# 35    JDM Apartments, Dwarka, New Delhi, Delhi, India
# 36                               Sanskriti apartments
# 37                          Krishna Garden Apartments
# 38                                    Guru apartments
# 39                                  Kaveri Apartments
# 40                                 Gayatri apartments
# 41                                    Guru Apartments
# 42                                 Supriya Apartments
# 43                              Management Apartments
# 44                             Chandanwadi Apartments
# 45  Diamond Square Apartments, Plot No.13-A, Sector-6
# 46                                Prakriti Apartments
# 47            Millennium Apartments, Sector-9, Dwarka
# 48          shivalik apartments,  sector 9 , , dwarka
# 49          Green valley apartments, Dwarka sector 22
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 1   [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 2                                                  []  v-1663261238    False
# 3                                                  []  v-1663261238    False
# 4   [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 5   [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 6   [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 7   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1663261238    False
# 8   [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 9   [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 10  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...  v-1663261238    False
# 11  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 12  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 13  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 14  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 15  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...  v-1663261238    False
# 16  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 17  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 18  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 19  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 20  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 21  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 22                                                 []  v-1663261238    False
# 23  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 24  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 25  [{'id': '4f2a210c4b9023bd5841ed28', 'name': 'H...  v-1663261238    False
# 26  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 27  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 28  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 29  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 30  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 31  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 32  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 33  [{'id': '4bf58dd8d48988d1f8931735', 'name': 'B...  v-1663261238    False
# 34  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 35  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 36                                                 []  v-1663261238    False
# 37  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 38  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 39  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 40  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 41  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 42  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 43  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...  v-1663261238    False
# 44  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 45  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 46  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 47                                                 []  v-1663261238    False
# 48  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
# 49  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1663261238    False
#
#                     location.address  location.lat  location.lng  \
# 0                      Sec 4, Dwarka     28.601269     77.048880
# 1                             Dwarka     28.596122     77.045318
# 2                    Sector 3 Dwarka     28.603650     77.040910
# 3                                NaN     28.604821     77.042990
# 4                            U Block     28.495667     77.095830
# 5                                NaN     28.593309     77.047081
# 6                          Plot No.8     28.603310     77.051254
# 7            Block b , Plot Num 226,     28.577158     77.047214
# 8                                NaN     28.588090     77.063409
# 9   Plot No. - 12, Dwarka Sector - 9     28.583254     77.066298
# 10             Sector 23, Plot no. 5     28.562260     77.055954
# 11                 Sector 23, Plot 2     28.560323     77.054060
# 12                               NaN     28.562868     77.051080
# 13                  Sector 7 Plot 15     28.579831     77.075499
# 14                               NaN     28.602858     77.030830
# 15                            Dwarka     28.592082     77.036946
# 16                  Dwarka Sector 12     28.591983     77.036219
# 17                Sector -18, Dwarka     28.588301     77.034635
# 18                         Sector 11     28.594488     77.048632
# 19                               NaN     28.544138     77.074480
# 20                               NaN     28.590326     77.038920
# 21                               NaN     28.605143     77.040544
# 22                Sector 16 Kakraula     28.610437     77.022175
# 23   Plot No. - 19, Sector 4, Dwarka     28.602051     77.043760
# 24                               NaN     28.603441     77.045290
# 25                               NaN     28.590746     77.042061
# 26                               NaN     28.603264     77.040466
# 27                               NaN     28.605714     77.041171
# 28                  Sector 3, Dwarka     28.618631     77.031953
# 29       Pocket-4, Sector-11, Dwarka     28.586996     77.044711
# 30                               NaN     28.586661     77.049182
# 31               Plot No 16 Sector 4     28.603919     77.046746
# 32                   Rama Apartments     28.595118     77.052065
# 33   52 Hanuman Road Connaught Place     28.630239     77.215981
# 34   Plot No. 11, Sector - 4, Dwarka     28.597604     77.054695
# 35                    JDM Apartments     28.601460     77.057462
# 36                        Sector 19B     28.575641     77.045093
# 37                         Sector 19     28.573285     77.045093
# 38               Plot no.2, Sector 6     28.592392     77.059167
# 39                               NaN     28.595370     77.060210
# 40                  Plot 9, sector 9     28.581497     77.067845
# 41                            Plot 2     28.592395     77.059255
# 42    Plot No. 20, Sector 10, Dwarka     28.586663     77.054479
# 43                          Plot -17     28.596674     77.060913
# 44                         Sector 10     28.586485     77.063076
# 45                               NaN     28.595078     77.066879
# 46                          Sector 6     28.589801     77.066011
# 47                               NaN     28.577919     77.070514
# 48                Shivalik Apartment     28.581524     77.065987
# 49                               NaN     28.558989     77.059390
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 28.60126874658018...               2784
# 1   [{'label': 'display', 'lat': 28.59612162667995...               2348
# 2   [{'label': 'display', 'lat': 28.60365, 'lng': ...               2147
# 3   [{'label': 'display', 'lat': 28.60482076779481...               2388
# 4   [{'label': 'display', 'lat': 28.49566694001060...              13232
# 5   [{'label': 'display', 'lat': 28.59330940246582...               2523
# 6   [{'label': 'display', 'lat': 28.60331, 'lng': ...               3071
# 7   [{'label': 'display', 'lat': 28.577158, 'lng':...               3209
# 8   [{'label': 'display', 'lat': 28.58809001776062...               4182
# 9   [{'label': 'display', 'lat': 28.583254, 'lng':...               4582
# 10  [{'label': 'display', 'lat': 28.56225972318951...               4965
# 11  [{'label': 'display', 'lat': 28.56032324683900...               5005
# 12  [{'label': 'display', 'lat': 28.562868, 'lng':...               4601
# 13  [{'label': 'display', 'lat': 28.57983110744415...               5554
# 14  [{'label': 'display', 'lat': 28.602858, 'lng':...               1283
# 15  [{'label': 'display', 'lat': 28.59208181977578...               1558
# 16  [{'label': 'display', 'lat': 28.59198298363959...               1491
# 17  [{'label': 'display', 'lat': 28.58830112805655...               1493
# 18  [{'label': 'display', 'lat': 28.59448847506889...               2669
# 19  [{'label': 'display', 'lat': 28.5441381, 'lng'...               7676
# 20  [{'label': 'display', 'lat': 28.59032629182056...               1793
# 21  [{'label': 'display', 'lat': 28.60514338164026...               2197
# 22  [{'label': 'display', 'lat': 28.61043720901799...               1731
# 23  [{'label': 'display', 'lat': 28.60205077371315...               2332
# 24  [{'label': 'display', 'lat': 28.60344142721175...               2527
# 25  [{'label': 'display', 'lat': 28.59074592590332...               2078
# 26  [{'label': 'display', 'lat': 28.603264, 'lng':...               2089
# 27  [{'label': 'display', 'lat': 28.60571382763927...               2282
# 28  [{'label': 'display', 'lat': 28.61863088340912...               2838
# 29  [{'label': 'display', 'lat': 28.58699570523034...               2449
# 30  [{'label': 'display', 'lat': 28.586661, 'lng':...               2872
# 31  [{'label': 'display', 'lat': 28.60391853378081...               2679
# 32  [{'label': 'display', 'lat': 28.59511849807072...               3004
# 33  [{'label': 'display', 'lat': 28.63023926234120...              19424
# 34  [{'label': 'display', 'lat': 28.59760447061139...               3275
# 35  [{'label': 'display', 'lat': 28.60145953308482...               3606
# 36  [{'label': 'display', 'lat': 28.57564053869893...               3161
# 37  [{'label': 'display', 'lat': 28.57328493842414...               3344
# 38  [{'label': 'display', 'lat': 28.592392, 'lng':...               3709
# 39  [{'label': 'display', 'lat': 28.59537, 'lng': ...               3800
# 40  [{'label': 'display', 'lat': 28.58149673147423...               4785
# 41  [{'label': 'display', 'lat': 28.592395, 'lng':...               3717
# 42  [{'label': 'display', 'lat': 28.586663, 'lng':...               3367
# 43  [{'label': 'display', 'lat': 28.59667379414442...               3874
# 44  [{'label': 'display', 'lat': 28.586485, 'lng':...               4186
# 45  [{'label': 'display', 'lat': 28.59507751464843...               4452
# 46  [{'label': 'display', 'lat': 28.58980113598406...               4404
# 47  [{'label': 'display', 'lat': 28.57791888003877...               5166
# 48  [{'label': 'display', 'lat': 28.58152389526367...               4612
# 49  [{'label': 'display', 'lat': 28.55898934868230...               5461
#
#    location.cc location.country  \
# 0           IN            India
# 1           IN            India
# 2           IN            India
# 3           IN            India
# 4           IN            India
# 5           IN            India
# 6           IN            India
# 7           IN            India
# 8           IN            India
# 9           IN            India
# 10          IN            India
# 11          IN            India
# 12          IN            India
# 13          IN            India
# 14          IN            India
# 15          IN            India
# 16          IN            India
# 17          IN            India
# 18          IN            India
# 19          IN            India
# 20          IN            India
# 21          IN            India
# 22          IN            India
# 23          IN            India
# 24          IN            India
# 25          IN            India
# 26          IN            India
# 27          IN            India
# 28          IN            India
# 29          IN            India
# 30          IN            India
# 31          IN            India
# 32          IN            India
# 33          IN            India
# 34          IN            India
# 35          IN            India
# 36          IN            India
# 37          IN            India
# 38          IN            India
# 39          IN            India
# 40          IN            India
# 41          IN            India
# 42          IN            India
# 43          IN            India
# 44          IN            India
# 45          IN            India
# 46          IN            India
# 47          IN            India
# 48          IN            India
# 49          IN            India
#
#                             location.formattedAddress location.city  \
# 0                              [Sec 4, Dwarka, India]           NaN
# 1                   [Dwarka, New Delhi, Delhi, India]     New Delhi
# 2   [Sector 3 Dwarka (Azad Hind Fauz Road), New De...     New Delhi
# 3                                             [India]           NaN
# 4   [U Block (21/20), Gurgaon 122001, Haryāna, India]       Gurgaon
# 5                                             [India]           NaN
# 6   [Plot No.8 (Sector 4), New Delhi 110075, Delhi...     New Delhi
# 7   [Block b , Plot Num 226, (Near Mother Dairy), ...     New Delhi
# 8                                             [India]           NaN
# 9   [Plot No. - 12, Dwarka Sector - 9, New Delhi 1...     New Delhi
# 10   [Sector 23, Plot no. 5, New Delhi, Delhi, India]     New Delhi
# 11  [Sector 23, Plot 2 (Dwarka), New Delhi 110075,...     New Delhi
# 12                   [New Delhi 110077, Delhi, India]     New Delhi
# 13   [Sector 7 Plot 15 (Dwarka), Delhi, Delhi, India]         Delhi
# 14                       [Delhi 110078, Delhi, India]         Delhi
# 15           [Dwarka, New Delhi 110078, Delhi, India]     New Delhi
# 16  [Dwarka Sector 12 (Road 205), New Delhi 110078...     New Delhi
# 17   [Sector -18, Dwarka, Delhi 110078, Delhi, India]         Delhi
# 18        [Sector 11, New Delhi 110085, Delhi, India]     New Delhi
# 19                                            [India]           NaN
# 20                                            [India]           NaN
# 21                                            [India]           NaN
# 22          [Sector 16 Kakraula, Delhi, Delhi, India]         Delhi
# 23  [Plot No. - 19, Sector 4, Dwarka, New Delhi, D...     New Delhi
# 24                                            [India]           NaN
# 25                                            [India]           NaN
# 26                                            [India]           NaN
# 27                                            [India]           NaN
# 28                          [Sector 3, Dwarka, India]           NaN
# 29  [Pocket-4, Sector-11, Dwarka, New Delhi 110075...     New Delhi
# 30                                            [India]           NaN
# 31  [Plot No 16 Sector 4 (Road No 201), Dwarka 110...        Dwarka
# 32  [Rama Apartments (Plot No 2, Sector 11), New D...     New Delhi
# 33  [52 Hanuman Road Connaught Place, New Delhi, D...     New Delhi
# 34  [Plot No. 11, Sector - 4, Dwarka, New Delhi 11...     New Delhi
# 35  [JDM Apartments (Plot No.11, Sector 5, Dwarka)...     New Delhi
# 36              [Sector 19B, New Delhi, Delhi, India]     New Delhi
# 37               [Sector 19, New Delhi, Delhi, India]     New Delhi
# 38  [Plot no.2, Sector 6 (Dwarka), New Delhi 11007...     New Delhi
# 39                   [New Delhi 110075, Delhi, India]     New Delhi
# 40  [Plot 9, sector 9, New Delhi 110075, Delhi, In...     New Delhi
# 41  [Plot 2 (Sector 6, dwarka), New Delhi 110075, ...     New Delhi
# 42  [Plot No. 20, Sector 10, Dwarka (Opposite DDA ...     New Delhi
# 43  [Plot -17 (Sector 5, Dwarka), New Delhi, Delhi...     New Delhi
# 44  [Sector 10 (Dwarka), New Delhi 110075, Delhi, ...     New Delhi
# 45                                            [India]           NaN
# 46       [Sector 6 (Dwarka), New Delhi, Delhi, India]     New Delhi
# 47                                            [India]           NaN
# 48      [Shivalik Apartment, New Delhi, Delhi, India]     New Delhi
# 49                   [New Delhi 110077, Delhi, India]     New Delhi
#
#    location.state          location.crossStreet location.postalCode
# 0             NaN                           NaN                 NaN
# 1           Delhi                           NaN                 NaN
# 2           Delhi           Azad Hind Fauz Road              110078
# 3             NaN                           NaN                 NaN
# 4         Haryāna                         21/20              122001
# 5             NaN                           NaN                 NaN
# 6           Delhi                      Sector 4              110075
# 7           Delhi             Near Mother Dairy              110075
# 8             NaN                           NaN                 NaN
# 9           Delhi                           NaN              110077
# 10          Delhi                           NaN                 NaN
# 11          Delhi                        Dwarka              110075
# 12          Delhi                           NaN              110077
# 13          Delhi                        Dwarka                 NaN
# 14          Delhi                           NaN              110078
# 15          Delhi                           NaN              110078
# 16          Delhi                      Road 205              110078
# 17          Delhi                           NaN              110078
# 18          Delhi                           NaN              110085
# 19            NaN                           NaN                 NaN
# 20            NaN                           NaN                 NaN
# 21            NaN                           NaN                 NaN
# 22          Delhi                           NaN                 NaN
# 23          Delhi                           NaN                 NaN
# 24            NaN                           NaN                 NaN
# 25            NaN                           NaN                 NaN
# 26            NaN                           NaN                 NaN
# 27            NaN                           NaN                 NaN
# 28            NaN                           NaN                 NaN
# 29          Delhi                           NaN              110075
# 30            NaN                           NaN                 NaN
# 31          Delhi                   Road No 201              110078
# 32          Delhi          Plot No 2, Sector 11              110075
# 33          Delhi                           NaN                 NaN
# 34          Delhi                           NaN              110075
# 35          Delhi  Plot No.11, Sector 5, Dwarka              110075
# 36          Delhi                           NaN                 NaN
# 37          Delhi                           NaN                 NaN
# 38          Delhi                        Dwarka              110075
# 39          Delhi                           NaN              110075
# 40          Delhi                           NaN              110075
# 41  Delhi (state)              Sector 6, dwarka              110075
# 42          Delhi   Opposite DDA Sports Complex                 NaN
# 43          Delhi              Sector 5, Dwarka                 NaN
# 44          Delhi                        Dwarka              110075
# 45            NaN                           NaN                 NaN
# 46          Delhi                        Dwarka                 NaN
# 47            NaN                           NaN                 NaN
# 48          Delhi                           NaN                 NaN
# 49          Delhi                           NaN              110077

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered.drop(dataframe_filtered[(dataframe_filtered['distance'] >10000)].index,inplace=True) #remove some unwanted locations(too far away etc.)
dataframe_filtered.drop(['cc','country','state','city'],axis=1,inplace=True) #no need for those columns as we know we're in Delhi,IN
dataframe_filtered.head(n = n)
# Out:
#                                                  name  \
# 0                                  Ispatika Apartment
# 1                            Shivam,Apartment, Sec 12
# 2   National Apartment Sector 3, Near sec3/13 traf...
# 3                  national apartment sector 3 dwarka
# 5                           gokul apartment sector 11
# 6                               South Delhi Apartment
# 7               Oyo 37722 Silver Oak Luxury Apartment
# 8                  skylark apartment dwarka sector 06
# 9                                Sukh Sagar Apartment
# 10                                 Airlines Apartment
# 11                           New Millenium Apartments
# 12                         Ramakrishan Cghs Apartment
# 13                     St. Columba's School Apartment
# 14                                Kautilya Apartments
# 15                                Highland Apartments
# 16                                  Sunder Apartments
# 17                              Prem Milan Apartments
# 18                              Gold Croft Apartments
# 19          Admiral apartment, emeryville, california
# 20                                Radisson Apartments
# 21        Air India Apartments,Sector 3,Plot 9,Dwarka
# 22                             Silver Arch Apartments
# 23                             Dakshinayan Apartments
# 24        Air India Apartments,Sector 3,Plot 9,Dwarka
# 25                                 Sunrise Apartments
# 26              National Apartments, Sector 3, Dwarka
# 27              himachali apartments, dwarka sector-3
# 28                               Air India Apartments
# 29                                Sun View Apartments
# 30                              Akshardham Apartments
# 31                                     DPS Apartments
# 32                                    Rama Apartments
# 34                                     PNB Apartments
# 35    JDM Apartments, Dwarka, New Delhi, Delhi, India
# 36                               Sanskriti apartments
# 37                          Krishna Garden Apartments
# 38                                    Guru apartments
# 39                                  Kaveri Apartments
# 40                                 Gayatri apartments
# 41                                    Guru Apartments
# 42                                 Supriya Apartments
# 43                              Management Apartments
# 44                             Chandanwadi Apartments
# 45  Diamond Square Apartments, Plot No.13-A, Sector-6
# 46                                Prakriti Apartments
# 47            Millennium Apartments, Sector-9, Dwarka
# 48          shivalik apartments,  sector 9 , , dwarka
# 49          Green valley apartments, Dwarka sector 22
#
#                                   categories  \
# 0   Residential Building (Apartment / Condo)
# 1   Residential Building (Apartment / Condo)
# 2                                       None
# 3                                       None
# 5   Residential Building (Apartment / Condo)
# 6   Residential Building (Apartment / Condo)
# 7                                      Hotel
# 8   Residential Building (Apartment / Condo)
# 9   Residential Building (Apartment / Condo)
# 10                                  Building
# 11  Residential Building (Apartment / Condo)
# 12  Residential Building (Apartment / Condo)
# 13  Residential Building (Apartment / Condo)
# 14  Residential Building (Apartment / Condo)
# 15                                  Building
# 16  Residential Building (Apartment / Condo)
# 17  Residential Building (Apartment / Condo)
# 18  Residential Building (Apartment / Condo)
# 19  Residential Building (Apartment / Condo)
# 20  Residential Building (Apartment / Condo)
# 21  Residential Building (Apartment / Condo)
# 22                                      None
# 23  Residential Building (Apartment / Condo)
# 24  Residential Building (Apartment / Condo)
# 25                       Housing Development
# 26  Residential Building (Apartment / Condo)
# 27  Residential Building (Apartment / Condo)
# 28  Residential Building (Apartment / Condo)
# 29  Residential Building (Apartment / Condo)
# 30  Residential Building (Apartment / Condo)
# 31  Residential Building (Apartment / Condo)
# 32  Residential Building (Apartment / Condo)
# 34  Residential Building (Apartment / Condo)
# 35  Residential Building (Apartment / Condo)
# 36                                      None
# 37  Residential Building (Apartment / Condo)
# 38  Residential Building (Apartment / Condo)
# 39  Residential Building (Apartment / Condo)
# 40  Residential Building (Apartment / Condo)
# 41  Residential Building (Apartment / Condo)
# 42  Residential Building (Apartment / Condo)
# 43                                  Building
# 44  Residential Building (Apartment / Condo)
# 45  Residential Building (Apartment / Condo)
# 46  Residential Building (Apartment / Condo)
# 47                                      None
# 48  Residential Building (Apartment / Condo)
# 49  Residential Building (Apartment / Condo)
#
#                              address        lat        lng  \
# 0                      Sec 4, Dwarka  28.601269  77.048880
# 1                             Dwarka  28.596122  77.045318
# 2                    Sector 3 Dwarka  28.603650  77.040910
# 3                                NaN  28.604821  77.042990
# 5                                NaN  28.593309  77.047081
# 6                          Plot No.8  28.603310  77.051254
# 7            Block b , Plot Num 226,  28.577158  77.047214
# 8                                NaN  28.588090  77.063409
# 9   Plot No. - 12, Dwarka Sector - 9  28.583254  77.066298
# 10             Sector 23, Plot no. 5  28.562260  77.055954
# 11                 Sector 23, Plot 2  28.560323  77.054060
# 12                               NaN  28.562868  77.051080
# 13                  Sector 7 Plot 15  28.579831  77.075499
# 14                               NaN  28.602858  77.030830
# 15                            Dwarka  28.592082  77.036946
# 16                  Dwarka Sector 12  28.591983  77.036219
# 17                Sector -18, Dwarka  28.588301  77.034635
# 18                         Sector 11  28.594488  77.048632
# 19                               NaN  28.544138  77.074480
# 20                               NaN  28.590326  77.038920
# 21                               NaN  28.605143  77.040544
# 22                Sector 16 Kakraula  28.610437  77.022175
# 23   Plot No. - 19, Sector 4, Dwarka  28.602051  77.043760
# 24                               NaN  28.603441  77.045290
# 25                               NaN  28.590746  77.042061
# 26                               NaN  28.603264  77.040466
# 27                               NaN  28.605714  77.041171
# 28                  Sector 3, Dwarka  28.618631  77.031953
# 29       Pocket-4, Sector-11, Dwarka  28.586996  77.044711
# 30                               NaN  28.586661  77.049182
# 31               Plot No 16 Sector 4  28.603919  77.046746
# 32                   Rama Apartments  28.595118  77.052065
# 34   Plot No. 11, Sector - 4, Dwarka  28.597604  77.054695
# 35                    JDM Apartments  28.601460  77.057462
# 36                        Sector 19B  28.575641  77.045093
# 37                         Sector 19  28.573285  77.045093
# 38               Plot no.2, Sector 6  28.592392  77.059167
# 39                               NaN  28.595370  77.060210
# 40                  Plot 9, sector 9  28.581497  77.067845
# 41                            Plot 2  28.592395  77.059255
# 42    Plot No. 20, Sector 10, Dwarka  28.586663  77.054479
# 43                          Plot -17  28.596674  77.060913
# 44                         Sector 10  28.586485  77.063076
# 45                               NaN  28.595078  77.066879
# 46                          Sector 6  28.589801  77.066011
# 47                               NaN  28.577919  77.070514
# 48                Shivalik Apartment  28.581524  77.065987
# 49                               NaN  28.558989  77.059390
#
#                                        labeledLatLngs  distance  \
# 0   [{'label': 'display', 'lat': 28.60126874658018...      2784
# 1   [{'label': 'display', 'lat': 28.59612162667995...      2348
# 2   [{'label': 'display', 'lat': 28.60365, 'lng': ...      2147
# 3   [{'label': 'display', 'lat': 28.60482076779481...      2388
# 5   [{'label': 'display', 'lat': 28.59330940246582...      2523
# 6   [{'label': 'display', 'lat': 28.60331, 'lng': ...      3071
# 7   [{'label': 'display', 'lat': 28.577158, 'lng':...      3209
# 8   [{'label': 'display', 'lat': 28.58809001776062...      4182
# 9   [{'label': 'display', 'lat': 28.583254, 'lng':...      4582
# 10  [{'label': 'display', 'lat': 28.56225972318951...      4965
# 11  [{'label': 'display', 'lat': 28.56032324683900...      5005
# 12  [{'label': 'display', 'lat': 28.562868, 'lng':...      4601
# 13  [{'label': 'display', 'lat': 28.57983110744415...      5554
# 14  [{'label': 'display', 'lat': 28.602858, 'lng':...      1283
# 15  [{'label': 'display', 'lat': 28.59208181977578...      1558
# 16  [{'label': 'display', 'lat': 28.59198298363959...      1491
# 17  [{'label': 'display', 'lat': 28.58830112805655...      1493
# 18  [{'label': 'display', 'lat': 28.59448847506889...      2669
# 19  [{'label': 'display', 'lat': 28.5441381, 'lng'...      7676
# 20  [{'label': 'display', 'lat': 28.59032629182056...      1793
# 21  [{'label': 'display', 'lat': 28.60514338164026...      2197
# 22  [{'label': 'display', 'lat': 28.61043720901799...      1731
# 23  [{'label': 'display', 'lat': 28.60205077371315...      2332
# 24  [{'label': 'display', 'lat': 28.60344142721175...      2527
# 25  [{'label': 'display', 'lat': 28.59074592590332...      2078
# 26  [{'label': 'display', 'lat': 28.603264, 'lng':...      2089
# 27  [{'label': 'display', 'lat': 28.60571382763927...      2282
# 28  [{'label': 'display', 'lat': 28.61863088340912...      2838
# 29  [{'label': 'display', 'lat': 28.58699570523034...      2449
# 30  [{'label': 'display', 'lat': 28.586661, 'lng':...      2872
# 31  [{'label': 'display', 'lat': 28.60391853378081...      2679
# 32  [{'label': 'display', 'lat': 28.59511849807072...      3004
# 34  [{'label': 'display', 'lat': 28.59760447061139...      3275
# 35  [{'label': 'display', 'lat': 28.60145953308482...      3606
# 36  [{'label': 'display', 'lat': 28.57564053869893...      3161
# 37  [{'label': 'display', 'lat': 28.57328493842414...      3344
# 38  [{'label': 'display', 'lat': 28.592392, 'lng':...      3709
# 39  [{'label': 'display', 'lat': 28.59537, 'lng': ...      3800
# 40  [{'label': 'display', 'lat': 28.58149673147423...      4785
# 41  [{'label': 'display', 'lat': 28.592395, 'lng':...      3717
# 42  [{'label': 'display', 'lat': 28.586663, 'lng':...      3367
# 43  [{'label': 'display', 'lat': 28.59667379414442...      3874
# 44  [{'label': 'display', 'lat': 28.586485, 'lng':...      4186
# 45  [{'label': 'display', 'lat': 28.59507751464843...      4452
# 46  [{'label': 'display', 'lat': 28.58980113598406...      4404
# 47  [{'label': 'display', 'lat': 28.57791888003877...      5166
# 48  [{'label': 'display', 'lat': 28.58152389526367...      4612
# 49  [{'label': 'display', 'lat': 28.55898934868230...      5461
#
#                                      formattedAddress  \
# 0                              [Sec 4, Dwarka, India]
# 1                   [Dwarka, New Delhi, Delhi, India]
# 2   [Sector 3 Dwarka (Azad Hind Fauz Road), New De...
# 3                                             [India]
# 5                                             [India]
# 6   [Plot No.8 (Sector 4), New Delhi 110075, Delhi...
# 7   [Block b , Plot Num 226, (Near Mother Dairy), ...
# 8                                             [India]
# 9   [Plot No. - 12, Dwarka Sector - 9, New Delhi 1...
# 10   [Sector 23, Plot no. 5, New Delhi, Delhi, India]
# 11  [Sector 23, Plot 2 (Dwarka), New Delhi 110075,...
# 12                   [New Delhi 110077, Delhi, India]
# 13   [Sector 7 Plot 15 (Dwarka), Delhi, Delhi, India]
# 14                       [Delhi 110078, Delhi, India]
# 15           [Dwarka, New Delhi 110078, Delhi, India]
# 16  [Dwarka Sector 12 (Road 205), New Delhi 110078...
# 17   [Sector -18, Dwarka, Delhi 110078, Delhi, India]
# 18        [Sector 11, New Delhi 110085, Delhi, India]
# 19                                            [India]
# 20                                            [India]
# 21                                            [India]
# 22          [Sector 16 Kakraula, Delhi, Delhi, India]
# 23  [Plot No. - 19, Sector 4, Dwarka, New Delhi, D...
# 24                                            [India]
# 25                                            [India]
# 26                                            [India]
# 27                                            [India]
# 28                          [Sector 3, Dwarka, India]
# 29  [Pocket-4, Sector-11, Dwarka, New Delhi 110075...
# 30                                            [India]
# 31  [Plot No 16 Sector 4 (Road No 201), Dwarka 110...
# 32  [Rama Apartments (Plot No 2, Sector 11), New D...
# 34  [Plot No. 11, Sector - 4, Dwarka, New Delhi 11...
# 35  [JDM Apartments (Plot No.11, Sector 5, Dwarka)...
# 36              [Sector 19B, New Delhi, Delhi, India]
# 37               [Sector 19, New Delhi, Delhi, India]
# 38  [Plot no.2, Sector 6 (Dwarka), New Delhi 11007...
# 39                   [New Delhi 110075, Delhi, India]
# 40  [Plot 9, sector 9, New Delhi 110075, Delhi, In...
# 41  [Plot 2 (Sector 6, dwarka), New Delhi 110075, ...
# 42  [Plot No. 20, Sector 10, Dwarka (Opposite DDA ...
# 43  [Plot -17 (Sector 5, Dwarka), New Delhi, Delhi...
# 44  [Sector 10 (Dwarka), New Delhi 110075, Delhi, ...
# 45                                            [India]
# 46       [Sector 6 (Dwarka), New Delhi, Delhi, India]
# 47                                            [India]
# 48      [Shivalik Apartment, New Delhi, Delhi, India]
# 49                   [New Delhi 110077, Delhi, India]
#
#                      crossStreet postalCode                        id
# 0                            NaN        NaN  4edb45ac0aaf49e02aa30cc3
# 1                            NaN        NaN  5184977d498ec7f6416fdcba
# 2            Azad Hind Fauz Road     110078  4efe8845b6346feaeba89dc0
# 3                            NaN        NaN  4efe88f3775bec6b42df0632
# 5                            NaN        NaN  516a4e8ee4b01de80d736d8e
# 6                       Sector 4     110075  578ee93c498e2a11e7647c58
# 7              Near Mother Dairy     110075  5fcbc2c14a774867c404be66
# 8                            NaN        NaN  4ffb9c40e4b02d09f9b5ff9e
# 9                            NaN     110077  5736bade498e8349f57ac805
# 10                           NaN        NaN  4c4ac136712ac9289c08e96b
# 11                        Dwarka     110075  5117d231e4b05b41f518d44a
# 12                           NaN     110077  59733a8ceacf453223eced6f
# 13                        Dwarka        NaN  5524d6d1498e63d1181af446
# 14                           NaN     110078  5c43189dbed483002cbccbe6
# 15                           NaN     110078  4d73a5a85838a093a9a91bdb
# 16                      Road 205     110078  518f6480498e01b5206fb6dc
# 17                           NaN     110078  52072b3211d27144358667a1
# 18                           NaN     110085  4e2c294045dd3272c819f73d
# 19                           NaN        NaN  4f76cc8ae4b07024f9ebc63c
# 20                           NaN        NaN  52b9e116498e97c256cfe787
# 21                           NaN        NaN  4f3522f5e4b0cbcdf07934ca
# 22                           NaN        NaN  5038dd2be4b03267a8a2c78e
# 23                           NaN        NaN  4deae91d88774880e32a49a0
# 24                           NaN        NaN  4f3523f8e4b0ba1c47e23658
# 25                           NaN        NaN  504320efe4b043734b779629
# 26                           NaN        NaN  51694ebce4b0c884cc777a0f
# 27                           NaN        NaN  50004cbfe4b086e5a770dfe0
# 28                           NaN        NaN  50f2c04de4b0d3754e3b94b0
# 29                           NaN     110075  5220e0df11d2303d8d1bc3cf
# 30                           NaN        NaN  55fa984c498e3cf080b0c6e6
# 31                   Road No 201     110078  5659a3f6498e4fd2385189ef
# 32          Plot No 2, Sector 11     110075  4df77345d22df20cc2d76c35
# 34                           NaN     110075  5058947ae4b0b2cff7f523e0
# 35  Plot No.11, Sector 5, Dwarka     110075  4f849baee5e8be643de1b858
# 36                           NaN        NaN  4df8131d18385456c7f3d470
# 37                           NaN        NaN  536d260f11d2642ca67193e9
# 38                        Dwarka     110075  4d3b32fc687ca35dc88891c4
# 39                           NaN     110075  5b82b4f71fa76300395ac927
# 40                           NaN     110075  4decf457fa76cc1b8b236e80
# 41              Sector 6, dwarka     110075  4e1b687218a8ce9e3860a54d
# 42   Opposite DDA Sports Complex        NaN  4e59fbf818a8c204751381dc
# 43              Sector 5, Dwarka        NaN  4e61fc66d22d509a396a222c
# 44                        Dwarka     110075  4df4607688772e1f81574569
# 45                           NaN        NaN  518a94a1498e5063a8a381f7
# 46                        Dwarka        NaN  4df6314ca809141629ab4dd2
# 47                           NaN        NaN  4e1cf2bac65b6cd0da96baa8
# 48                           NaN        NaN  52bfdb2e498e3dae8e50b3c6
# 49                           NaN     110077  4f43e6a8e4b011b008069090

# %% [markdown]
# Let us plot all these potential locations on a map of Delhi:

# %%
#define coordinates of the college
map_bang=folium.Map(location=[28.6096354,77.0926795],zoom_start=12)
# instantiate a feature group for the incidents in the dataframe
locations = folium.map.FeatureGroup()

latitudes = list(dataframe_filtered.lat)
longitudes = list( dataframe_filtered.lng)
labels = list(dataframe_filtered.name)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(map_bang)    
    
# add incidents to map
map_bang.add_child(locations)

# add incidents to map
map_bang.add_child(locations)

map_bang
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b5c0433472e8ccbdcf68991d49191a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b5c0433472e8ccbdcf68991d49191a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4b5c0433472e8ccbdcf68991d49191a3 = L.map(
#                 &quot;map_4b5c0433472e8ccbdcf68991d49191a3&quot;,
#                 {
#                     center: [28.6096354, 77.0926795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63650bc332bcf51fa17e3f01237651ca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4b5c0433472e8ccbdcf68991d49191a3);
#
#
#             var marker_7b36c03117555c99912264e59468ab62 = L.marker(
#                 [28.60126874658018, 77.04887984267545],
#                 {}
#             ).addTo(map_4b5c0433472e8ccbdcf68991d49191a3);
#
#
#         var popup_de02f19e85763159a605627f3e7d5685 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cc81c3d06476ca51aa1fdc76e0f20127 = $(`&lt;div id=&quot;html_cc81c3d06476ca51aa1fdc76e0f20127&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ispatika Apartment&lt;/div&gt;`)[0];
#             popup_de02f19e85763159a605627f3e7d5685.setContent(html_cc81c3d06476ca51aa1fdc76e0f20127);
#
#
#         marker_7b36c03117555c99912264e59468ab62.bindPopup(popup_de02f19e85763159a605627f3e7d5685)
#         ;
#
#
#
#
#             var marker_fe95ce2c2e8b4e9598d88a28d94ff27d = L.marker(
#                 [28.59612162667995, 77.04531777691248],
#                 {}
#             ).addTo(map_4b5c0433472e8ccbdcf68991d49191a3);
#
#
#         var popup_0f2fc3bc8fef39a3fbae86eafd08bd18 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e06db23df6c7724c5e5e92f2e3940c66 = $(`&lt;div id=&quot;html_e06db23df6c7724c5e5e92f2e3940c66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shivam,Apartment, Sec 12&lt;/div&gt;`)[0];
#             popup_0f2fc3bc8fef39a3fbae86eafd08bd18.setContent(html_e06db23df6c7724c5e5e92f2e3940c66);
#
#
#         marker_fe95ce2c2e8b4e9598d88a28d94ff27d.bindPopup(popup_0f2fc3bc8fef39a3fbae86eafd08bd18)
#         ;
#
#
#
#
#             var marker_b2cbf91af29c42941411ee8776d6b8ad = L.marker(
#                 [28.60365, 77.04091],
#                 {}
#             ).addTo(map_4b5c0433472e8ccbdcf68991d49191a3);
#
#
#         var popup_4d0dbea1dbe2acfe6bb2c6629056e7bb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_441d3bf04faecd1a131a6ce545ec6f56 = $(`&lt;div id=&quot;html_441d3bf04faecd1a131a6ce545ec6f56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;National Apartment Sector 3, Near sec3/13 traffic light&lt;/div&gt;`)[0];
#             popup_4d0dbea1dbe2acfe6bb2c6629056e7bb.setContent(html_441d3bf04faecd1a131a6ce545ec6f56);
#
#
#         marker_b2cbf91af29c42941411ee8776d6b8ad.bindPopup(popup_4d0dbea1dbe2acfe6bb2c6629056e7bb)
#         ;
#
#
#
#
#             var marker_1419532d370f706c9e08624570f27b74 = L.marker(
#                 [28.604820767794816, 77.04299017276543],
#                 {}
#             ).addTo(map_4b5c0433472e8ccbdcf68991d49191a3);
#
#
#         var popup_8a0808e44587eda1d5bcafd1fae240b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ba57ea21462516d17c62ea3724413bda = $(`&lt;div id=&quot;html_ba57ea21462516d17c62ea3724413bda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;national apartment sector 3 dwarka&lt;/div&gt;`)[0];
#             popup_8a0808e44587eda1d5bcafd1fae240b8.setContent(html_ba57ea21462516d17c62ea3724413bda);
#
#
#         marker_1419532d370f706c9e08624570f27b74.bindPopup(popup_8a0808e44587eda1d5bcafd1fae240b8)
#         ;
#
#
#
#
#             var marker_39c89197f0c12dfbf2202b061e72df65 = L.marker(
#                 [28.59330940246582, 77.04708099365234],
#                 {}
#             ).addTo(map_4b5c0433472e8ccbdcf68991d49191a3);
#
#
#         var popup_92d4d7e32f311ac0921a3247307e1a26 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fd77bae9623dce3216c5265d54c3a76e = $(`&lt;div id=&quot;html_fd77bae9623dce3216c5265d54c3a76e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;gokul apartment sector 11&lt;/div&gt;`)[0];
#             popup_92d4d7e32f311ac0921a3247307e1a26.setContent(html_fd77bae9623dce3216c5265d54c3a76e);
#
#
#         marker_39c89197f0c12dfbf2202b061e72df65.bindPopup(popup_92d4d7e32f311ac0921a3247307e1a26)
#         ;
#
#
#
#
#             var marker_e429e8347f919665cac10a5a36f05dc6 = L.marker(
#                 [28.60331, 77.051254],
#                 {}
#             ).addTo(map_4b5c0433472e8ccbdcf68991d49191a3);
#
#
#         var popup_8da7d02176de05430c6619012ab20d78 = L.popup({&quot;maxWidth&

# %% [markdown]
# Now, let's figure out which locations are ideal for which kinds of student.
#
# We will keep in mind the fact that the lower income students need a steady supply of fresh fruits, while the high income students need plenty of restaurant options to choose from.

# %%
df_evaluate=dataframe_filtered[['lat','lng']]
df_evaluate_a=dataframe_filtered[['lat','lng']]

# %%
RestList=[]
RestList_a=[]
latitudes = list(dataframe_filtered.lat)
longitudes = list( dataframe_filtered.lng)
for lat, lng in zip(latitudes, longitudes):    
    radius = 5000 #Set the radius to 5 kilometres for convenience
    latitude=lat#Query for the apartment location in question
    longitude=lng
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
    search_query = 'Restaurant' #Search for any food related locations
    results = requests.get(url).json()
    # assign relevant part of JSON to venues
    venues = results['response']['venues']
    # tranform venues into a dataframe
    dataframe2 = json_normalize(venues)
    filtered_columns = ['name', 'categories'] + [col for col in dataframe2.columns if col.startswith('location.')] + ['id']
    dataframe_filtered2 = dataframe2.loc[:, filtered_columns]
    # filter the category for each row
    dataframe_filtered2['categories'] = dataframe_filtered2.apply(get_category_type, axis=1)
    # clean column names by keeping only last term
    dataframe_filtered2.columns = [column.split('.')[-1] for column in dataframe_filtered2.columns]
    RestList.append(dataframe_filtered2['categories'].count())
    
    dataframe_filtered2_a = dataframe_filtered2[(dataframe_filtered2['distance'] <= 5000)]
    RestList_a.append(dataframe_filtered2_a['categories'].count())

# %%
df_evaluate['Restaurants']=RestList
df_evaluate_a['Restaurants']=RestList_a
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\3617986815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_evaluate['Restaurants']=RestList
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\3617986815.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_evaluate_a['Restaurants']=RestList_a

# %%
VegetableList=[]
VegetableList_a=[]
latitudes_2 = list(df_evaluate.lat)
longitudes_2 = list( df_evaluate.lng)
for lat, lng in zip(latitudes_2, longitudes_2):    
    radius = 10000 #Set the radius to 10 kilometres for convenience
    latitude=lat#Query for the apartment location in question
    longitude=lng
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
    search_query = 'Vegetable' #Search for any food related locations
    results = requests.get(url).json()
    # assign relevant part of JSON to venues
    venues = results['response']['venues']
    # tranform venues into a dataframe
    dataframe3 = json_normalize(venues)
    filtered_columns2 = ['name', 'categories'] + [col for col in dataframe3.columns if col.startswith('location.')] + ['id']
    dataframe_filtered3 = dataframe3.loc[:, filtered_columns2]
    # filter the category for each row
    dataframe_filtered3['categories'] = dataframe_filtered3.apply(get_category_type, axis=1)
    # clean column names by keeping only last term
    dataframe_filtered3.columns = [column.split('.')[-1] for column in dataframe_filtered3.columns]
    VegetableList.append(dataframe_filtered3['categories'].count())
    
    dataframe_filtered3_a = dataframe_filtered3[(dataframe_filtered3['distance'] <= 10000)]
    VegetableList_a.append(dataframe_filtered3_a['categories'].count())

# %%
df_evaluate['Fruits,Vegetables,Groceries']=VegetableList
df_evaluate_a['Fruits,Vegetables,Groceries']=VegetableList_a
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\297188932.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_evaluate['Fruits,Vegetables,Groceries']=VegetableList
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\297188932.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_evaluate_a['Fruits,Vegetables,Groceries']=VegetableList_a

# %%
kclusters = 3
df_evaluate.drop([df_evaluate.index[0]],inplace=True)
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_evaluate)
df_evaluate['Cluster']=kmeans.labels_
df_evaluate['Cluster']=df_evaluate['Cluster'].apply(str)
df_evaluate.head(100)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\2629108880.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_evaluate.drop([df_evaluate.index[0]],inplace=True)
# C:\Users\Acer\anaconda3\envs\myenv\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\2629108880.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_evaluate['Cluster']=kmeans.labels_
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\2629108880.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_evaluate['Cluster']=df_evaluate['Cluster'].apply(str)
#           lat        lng  Restaurants  Fruits,Vegetables,Groceries Cluster
# 1   28.596122  77.045318           12                            6       1
# 2   28.603650  77.040910           12                            4       1
# 3   28.604821  77.042990           12                            4       1
# 5   28.593309  77.047081           12                            5       1
# 6   28.603310  77.051254           12                            4       1
# 7   28.577158  77.047214            8                            6       2
# 8   28.588090  77.063409           12                            6       1
# 9   28.583254  77.066298           16                            7       0
# 10  28.562260  77.055954            7                            7       2
# 11  28.560323  77.054060           12                            7       1
# 12  28.562868  77.051080            7                            6       2
# 13  28.579831  77.075499           16                            7       0
# 14  28.602858  77.030830            9                            5       2
# 15  28.592082  77.036946            8                            6       2
# 16  28.591983  77.036219            8                            6       2
# 17  28.588301  77.034635            8                            5       2
# 18  28.594488  77.048632           12                            5       1
# 19  28.544138  77.074480           21                            9       0
# 20  28.590326  77.038920            8                            5       2
# 21  28.605143  77.040544           12                            4       1
# 22  28.610437  77.022175            8                            4       2
# 23  28.602051  77.043760           12                            5       1
# 24  28.603441  77.045290           12                            4       1
# 25  28.590746  77.042061            9                            5       2
# 26  28.603264  77.040466           11                            4       1
# 27  28.605714  77.041171           12                            4       1
# 28  28.618631  77.031953           10                            4       1
# 29  28.586996  77.044711            9                            5       2
# 30  28.586661  77.049182           12                            6       1
# 31  28.603919  77.046746           12                            4       1
# 32  28.595118  77.052065           12                            6       1
# 34  28.597604  77.054695           12                            5       1
# 35  28.601460  77.057462           15                            4       1
# 36  28.575641  77.045093            9                            6       2
# 37  28.573285  77.045093            6                            6       2
# 38  28.592392  77.059167           12                            6       1
# 39  28.595370  77.060210           12                            6       1
# 40  28.581497  77.067845           16                            7       0
# 41  28.592395  77.059255           12                            6       1
# 42  28.586663  77.054479           12                            7       1
# 43  28.596674  77.060913           12                            6       1
# 44  28.586485  77.063076           12                            7       1
# 45  28.595078  77.066879           12                            6       1
# 46  28.589801  77.066011           12                            7       1
# 47  28.577919  77.070514           16                            7       0
# 48  28.581524  77.065987           16                            7       0
# 49  28.558989  77.059390           13                           10       0

# %%
#define coordinates of the college
map_bang=folium.Map(location=[28.594899,77.021327],zoom_start=12)
# instantiate a feature group for the incidents in the dataframe
folium.Marker([28.594899, 77.021327], popup='GGSIPU').add_to(map_bang)
locations = folium.map.FeatureGroup()
# set color scheme for the clusters
def color_producer(cluster):
    if cluster=='0':
        return 'green'
    elif cluster=='1':
        return 'orange'
    else:
        return 'red'
latitudes = list(df_evaluate.lat)
longitudes = list(df_evaluate.lng)
labels = list(df_evaluate.Cluster)
dataframe_filtered.drop([dataframe_filtered.index[0]],inplace=True)
names=list(dataframe_filtered.name)
for lat, lng, label,names in zip(latitudes, longitudes, labels,names):
    folium.CircleMarker(
            [lat,lng],
            fill=True,
            fill_opacity=1,
            popup=folium.Popup(names, max_width = 300),
            radius=5,
            color=color_producer(label)
        ).add_to(map_bang)

# add locations to map
map_bang.add_child(locations)

map_bang
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1a56235987328af5c0a74290ee96c63 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1a56235987328af5c0a74290ee96c63&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e1a56235987328af5c0a74290ee96c63 = L.map(
#                 &quot;map_e1a56235987328af5c0a74290ee96c63&quot;,
#                 {
#                     center: [28.594899, 77.021327],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a319cc0d8dcb034f55fd12680308086 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e1a56235987328af5c0a74290ee96c63);
#
#
#             var marker_410cf8960084970a7dc6846f432cb435 = L.marker(
#                 [28.594899, 77.021327],
#                 {}
#             ).addTo(map_e1a56235987328af5c0a74290ee96c63);
#
#
#         var popup_3dffe2f248d4015ddc4b3c414dc22669 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1a9035b53bd8b47567b37e7f19dfa92e = $(`&lt;div id=&quot;html_1a9035b53bd8b47567b37e7f19dfa92e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GGSIPU&lt;/div&gt;`)[0];
#             popup_3dffe2f248d4015ddc4b3c414dc22669.setContent(html_1a9035b53bd8b47567b37e7f19dfa92e);
#
#
#         marker_410cf8960084970a7dc6846f432cb435.bindPopup(popup_3dffe2f248d4015ddc4b3c414dc22669)
#         ;
#
#
#
#
#             var circle_marker_7cd1975b18d21b842fa4ba3f10fde13e = L.circleMarker(
#                 [28.59612162667995, 77.04531777691248],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e1a56235987328af5c0a74290ee96c63);
#
#
#         var popup_9c7271d51088004e60cf25932fa5d384 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var html_258a8ccc686c3f4f3fdcce59835f22ab = $(`&lt;div id=&quot;html_258a8ccc686c3f4f3fdcce59835f22ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shivam,Apartment, Sec 12&lt;/div&gt;`)[0];
#             popup_9c7271d51088004e60cf25932fa5d384.setContent(html_258a8ccc686c3f4f3fdcce59835f22ab);
#
#
#         circle_marker_7cd1975b18d21b842fa4ba3f10fde13e.bindPopup(popup_9c7271d51088004e60cf25932fa5d384)
#         ;
#
#
#
#
#             var circle_marker_22ee95703ed39bc2727c98502560fea4 = L.circleMarker(
#                 [28.60365, 77.04091],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e1a56235987328af5c0a74290ee96c63);
#
#
#         var popup_a8f3404316129d5113d5e8a1e089da3b = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var html_ed9cb7629c85fbe5d8f58b5951ce965d = $(`&lt;div id=&quot;html_ed9cb7629c85fbe5d8f58b5951ce965d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;National Apartment Sector 3, Near sec3/13 traffic light&lt;/div&gt;`)[0];
#             popup_a8f3404316129d5113d5e8a1e089da3b.setContent(html_ed9cb7629c85fbe5d8f58b5951ce965d);
#
#
#         circle_marker_22ee95703ed39bc2727c98502560fea4.bindPopup(popup_a8f3404316129d5113d5e8a1e089da3b)
#         ;
#
#
#
#
#             var circle_marker_338115b372eac96fde0e5658e8d2040a = L.circleMarker(
#                 [28.604820767794816, 77.04299017276543],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e1a56235987328af5c0a74290ee96c63);
#
#
#         var popup_3fca00945c0eb02b77a76a4e059d7779 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var html_c383b96bd980129cf292142e71d70479 = $(`&lt;div id=&quot;html_c383b96bd980129cf292142e71d70479&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;national apartm

# %% [markdown]
# Applying K-Means, we find 3 prominent clusters:
#
# Cluster (Green) Where both (fruits and vegetables) and (restaurants) are abundant
#
# Cluster (orange): Restaurants are plentiful, but groceries less so.
#
# Cluster (Red): Restaurants and groceries are relatively hard to find.

# %%
kclusters = 3
df_evaluate_a.drop([df_evaluate_a.index[0]],inplace=True)
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_evaluate_a)
df_evaluate_a['Cluster']=kmeans.labels_
df_evaluate_a['Cluster']=df_evaluate_a['Cluster'].apply(str)
#df_evaluate_a.head(100)

#define coordinates of the college
map_bang=folium.Map(location=[28.594899,77.021327],zoom_start=12)
# instantiate a feature group for the incidents in the dataframe
folium.Marker([28.594899, 77.021327], popup='GGSIPU').add_to(map_bang)
locations = folium.map.FeatureGroup()
# set color scheme for the clusters
def color_producer(cluster):
    if cluster=='1':
        return 'green'
    elif cluster=='2':
        return 'orange'
    else:
        return 'red'
latitudes = list(df_evaluate_a.lat)
longitudes = list(df_evaluate_a.lng)
labels = list(df_evaluate_a.Cluster)
names=list(dataframe_filtered.name)
for lat, lng, label,names in zip(latitudes, longitudes, labels,names):
    folium.CircleMarker(
            [lat,lng],
            fill=True,
            fill_opacity=1,
            popup=folium.Popup(names, max_width = 300),
            radius=5,
            color=color_producer(label)
        ).add_to(map_bang)

# add locations to map
map_bang.add_child(locations)

map_bang
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\305263463.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_evaluate_a.drop([df_evaluate_a.index[0]],inplace=True)
# C:\Users\Acer\anaconda3\envs\myenv\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\305263463.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_evaluate_a['Cluster']=kmeans.labels_
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\305263463.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_evaluate_a['Cluster']=df_evaluate_a['Cluster'].apply(str)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ff353a5bf4a7af2af4ba6f36e2854ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ff353a5bf4a7af2af4ba6f36e2854ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7ff353a5bf4a7af2af4ba6f36e2854ca = L.map(
#                 &quot;map_7ff353a5bf4a7af2af4ba6f36e2854ca&quot;,
#                 {
#                     center: [28.594899, 77.021327],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d8bebb9a61725de5ea6f1b9e6c573b7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7ff353a5bf4a7af2af4ba6f36e2854ca);
#
#
#             var marker_b9e184cd32d7e45c82f25118a2e4a611 = L.marker(
#                 [28.594899, 77.021327],
#                 {}
#             ).addTo(map_7ff353a5bf4a7af2af4ba6f36e2854ca);
#
#
#         var popup_f62f2b80a33ea8fe5ba01f992fbb9d32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f91c4591497e72f3fa9b2223364b0142 = $(`&lt;div id=&quot;html_f91c4591497e72f3fa9b2223364b0142&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GGSIPU&lt;/div&gt;`)[0];
#             popup_f62f2b80a33ea8fe5ba01f992fbb9d32.setContent(html_f91c4591497e72f3fa9b2223364b0142);
#
#
#         marker_b9e184cd32d7e45c82f25118a2e4a611.bindPopup(popup_f62f2b80a33ea8fe5ba01f992fbb9d32)
#         ;
#
#
#
#
#             var circle_marker_8109ae8e157d59509176fcaddce657de = L.circleMarker(
#                 [28.59612162667995, 77.04531777691248],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7ff353a5bf4a7af2af4ba6f36e2854ca);
#
#
#         var popup_3db9c67cb117ac3ef53a47c94c35f321 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var html_2e73ce3ea34ef96d12bc2e302ee088e8 = $(`&lt;div id=&quot;html_2e73ce3ea34ef96d12bc2e302ee088e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shivam,Apartment, Sec 12&lt;/div&gt;`)[0];
#             popup_3db9c67cb117ac3ef53a47c94c35f321.setContent(html_2e73ce3ea34ef96d12bc2e302ee088e8);
#
#
#         circle_marker_8109ae8e157d59509176fcaddce657de.bindPopup(popup_3db9c67cb117ac3ef53a47c94c35f321)
#         ;
#
#
#
#
#             var circle_marker_50faf1691b7f9eda925e6bbc1c183e64 = L.circleMarker(
#                 [28.60365, 77.04091],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7ff353a5bf4a7af2af4ba6f36e2854ca);
#
#
#         var popup_0a68ec09aed1aa1d7ed962dc04068f55 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var html_df67b6e69922e8dbd2c5861df75c9a7b = $(`&lt;div id=&quot;html_df67b6e69922e8dbd2c5861df75c9a7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;National Apartment Sector 3, Near sec3/13 traffic light&lt;/div&gt;`)[0];
#             popup_0a68ec09aed1aa1d7ed962dc04068f55.setContent(html_df67b6e69922e8dbd2c5861df75c9a7b);
#
#
#         circle_marker_50faf1691b7f9eda925e6bbc1c183e64.bindPopup(popup_0a68ec09aed1aa1d7ed962dc04068f55)
#         ;
#
#
#
#
#             var circle_marker_a0f9e7c322ca7d753bc16f4946965173 = L.circleMarker(
#                 [28.604820767794816, 77.04299017276543],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7ff353a5bf4a7af2af4ba6f36e2854ca);
#
#
#         var popup_0016b821aa91de5887ede31e9865f98a = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var html_b829d32f380faaa4b831d4f09f8bf275 = $(`&lt;div id=&quot;html_b829d32f380faaa4b831d4f09f8bf275&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;national apartm

# %% [markdown]
# Applying K-Means, we find 3 prominent clusters:
#
# Cluster (Green) Where both (fruits and vegetables) and (restaurants) are abundant
#
# Cluster (Yellow): Restaurants are plentiful, but groceries less so.
#
# Cluster (Red): Restaurants and groceries are relatively hard to find.
#
# These are the clusters obtained after we clean up responses from the foursquare api and exclude results outside the specified range.

# %%
#df_evaluate_a['Cluster'] = df_evaluate_a['Cluster'].replace(['1','2'],['2','1'])
df_evaluate_a['Cluster'] = df_evaluate_a['Cluster'].replace({'1':'0','2':'1','0':'2'})

print("ConfusionMatrix \n",confusion_matrix(df_evaluate_a['Cluster'],df_evaluate['Cluster']))
print(classification_report(df_evaluate_a['Cluster'],df_evaluate['Cluster']))
# Out:
# ConfusionMatrix
#  [[ 1 14  0]
#  [ 5 11  0]
#  [ 1  2 13]]
#               precision    recall  f1-score   support
#
#            0       0.14      0.07      0.09        15
#            1       0.41      0.69      0.51        16
#            2       1.00      0.81      0.90        16
#
#     accuracy                           0.53        47
#    macro avg       0.52      0.52      0.50        47
# weighted avg       0.52      0.53      0.51        47
# C:\Users\Acer\AppData\Local\Temp\ipykernel_23360\2573040063.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_evaluate_a['Cluster'] = df_evaluate_a['Cluster'].replace({'1':'0','2':'1','0':'2'})

# %% [markdown]
# According to confusion matrix the clustering is 53% accurate.

# %% [markdown]
# ## Discussion

# %% [markdown]
# One can easily notice, the further away from the college, the more options one finds for food.
#
# The same can be said about other amenities as well.
#
# One thing I would like to note is that the foursquare data seems incomplete and at maximum gives us only 50 search results; Many locations seem to be missing or ill-classified leading to poor clustering.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Foursquare data is limited but can provide insights into a city’s infrastructure. This data could be supplemented with other sources to provide better results.
